# %% [markdown]
# <a href="https://colab.research.google.com/github/banditFox/introductionToNeuralNetworks/blob/main/INN_Learner_Notebook_Low_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><font size=6> Bank Churn Prediction </font></center>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# Businesses like banks which provide service have to worry about problem of 'Customer Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on improvement of service, keeping in mind these priorities.

# %% [markdown]
# ### Objective

# %% [markdown]
# You as a Data scientist with the  bank need to  build a neural network based classifier that can determine whether a customer will leave the bank  or not in the next 6 months.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# * CustomerId: Unique ID which is assigned to each customer
#
# * Surname: Last name of the customer
#
# * CreditScore: It defines the credit history of the customer.
#
# * Geography: A customer’s location
#
# * Gender: It defines the Gender of the customer
#
# * Age: Age of the customer
#
# * Tenure: Number of years for which the customer has been with the bank
#
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
#
# * Balance: Account balance
#
# * HasCrCard: It is a categorical variable which decides whether the customer has credit card or not.
#
# * EstimatedSalary: Estimated salary
#
# * IsActiveMember: Is is a categorical variable which decides whether the customer is active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions etc )
#
# * Exited : whether or not the customer left the bank within six month. It can take two values
#     - 0 = No ( Customer did not leave the bank )
#     - 1 = Yes ( Customer left the bank )

# %% [markdown]
# ## **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * Add the results/observations (wherever mentioned) derived from the analysis in the presentation and submit the same.

# %% [markdown]
# ## Importing necessary libraries

# %%
# Installing the libraries with the specified version.
# !pip install tensorflow==2.15.0 scikit-learn==1.2.2 seaborn==0.13.1 matplotlib==3.7.1 numpy==1.25.2 pandas==2.0.3 imbalanced-learn==0.10.1 -q --user

# %% [markdown]
# **Note:** After running the above cell, please restart the notebook kernel/runtime (depending on whether you're using Jupyter Notebook or Google Colab) and then sequentially run all cells from the one below.

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split

# library to import to standardize the data
from sklearn.preprocessing import StandardScaler, LabelEncoder

# importing different functions to build models
import tensorflow as tf
from tensorflow import keras
from keras import backend
from keras.models import Sequential
from keras.layers import Dense, Dropout

# importing SMOTE
from imblearn.over_sampling import SMOTE

# importing metrics
from sklearn.metrics import confusion_matrix,roc_curve,classification_report,recall_score

import random

# Library to avoid the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the dataset

# %%
# uncomment and run the following lines in case Colab is being used
from google.colab import drive
drive.mount('/content/drive')
path="/content/drive/MyDrive/PG_AIML/project4BankChurnPrediction/bank-1.csv"
# herpet=pd.read_csv(path)
# herpet.head()
# Out:
# Mounted at /content/drive

# %%
ds = pd.read_csv(path)    # complete the code to load the dataset

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### View the first and last 5 rows of the dataset.

# %%
# let's view the first 5 rows of the data
ds.head() ##  Complete the code to view top 5 rows of the data
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# let's view the last 5 rows of the data
ds.tail() ##  Complete the code to view last 5 rows of the data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %% [markdown]
# ### Understand the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
# Checking the number of rows and columns in the training data
print(f"There are:\n {ds.shape[0]} rows\n {ds.shape[1]} columns\n in the dataset") ##  Complete the code to view dimensions of the train data
# Out:
# There are:
#  10000 rows
#  14 columns
#  in the dataset

# %% [markdown]
# ### Check the data types of the columns for the dataset

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking the Statistical Summary

# %%
ds.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %% [markdown]
# ### Checking for Missing Values

# %%
# let's check for missing values in the data
ds.isnull().sum() ##  Complete the code to check missing entries in the train data
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### Checking for unique values for each of the column

# %%
ds.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
#RowNumber , CustomerId and Surname are unique hence dropping it
ds = ds.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# #### Observations on CreditScore

# %%
histogram_boxplot(ds,'CreditScore')

# %% [markdown]
# #### Observations on Age

# %%
# histogram_boxplot('__________________')
histogram_boxplot(ds, "Age", kde=True)          ## Complete the code to create histogram_boxplot for Age

# %% [markdown]
# #### Observations on Balance

# %%
# histogram_boxplot('__________________')
histogram_boxplot(ds, "Balance", kde=True)          ## Complete the code to create histogram_boxplot for Balance

# %% [markdown]
# #### Observations on Estimated Salary

# %%
# histogram_boxplot('__________________')          ## Complete the code to create histogram_boxplot for Estimated Salary
histogram_boxplot(ds, "EstimatedSalary", kde=True)

# %% [markdown]
# #### Observations on Exited

# %%
labeled_barplot(ds, "Exited", perc=True)

# %% [markdown]
# #### Observations on Geography

# %%
labeled_barplot(ds, "Geography", perc=True)               ## Complete the code to create labeled_barplot for Geography

# %% [markdown]
# #### Observations on Gender

# %%
# labeled_barplot('______________')               ## Complete the code to create labeled_barplot for Gender
labeled_barplot(ds, "Gender", perc=True)

# %% [markdown]
# #### Observations on Tenure

# %%
# labeled_barplot('______________')               ## Complete the code to create labeled_barplot for Tenure
labeled_barplot(ds, "Tenure", perc=True)

# %% [markdown]
# #### Observations on Number of Products

# %%
# labeled_barplot('______________')               ## Complete the code to create labeled_barplot for Number of products
labeled_barplot(ds, "NumOfProducts", perc=True)

# %% [markdown]
# #### Observations on Has Credit Card

# %%
# labeled_barplot('______________')               ## Complete the code to create labeled_barplot for Has credit card
labeled_barplot(ds, "HasCrCard", perc=True)

# %% [markdown]
# #### Observations on Is Active Member

# %%
# labeled_barplot('______________')               ## Complete the code to create labeled_barplot for Is active member
labeled_barplot(ds, "IsActiveMember", perc=True)

# %% [markdown]
# ### Bivariate Analysis

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %% [markdown]
# #### Correlation plot

# %%
# defining the list of numerical columns
cols_list = ["CreditScore","Age","Tenure","Balance","EstimatedSalary"]

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(ds[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# #### Exited Vs Geography

# %%
stacked_barplot(ds, "Geography", "Exited" )
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Gender

# %%
# stacked_barplot('__________')                   ## Complete the code to plot stacked barplot for Exited and Gender
stacked_barplot(ds, "Gender", "Exited" )
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Has Credit Card

# %%
# stacked_barplot('__________')                   ## Complete the code to plot stacked barplot for Exited and Has credit card
stacked_barplot(ds, "HasCrCard", "Exited" )
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Is active member

# %%
# stacked_barplot('__________')                   ## Complete the code to plot stacked barplot for Exited and Is active member
stacked_barplot(ds, "IsActiveMember", "Exited" )
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Credit Score

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='CreditScore',x='Exited',data=ds)
plt.show()

# %% [markdown]
# #### Exited Vs Age

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Age',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Age
plt.show()

# %% [markdown]
# #### Exited Vs Tenure

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Tenure',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Tenure
plt.show()

# %% [markdown]
# #### Exited Vs Balance

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Balance',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Balance
plt.show()

# %% [markdown]
# #### Exited Vs Number of Products

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='NumOfProducts',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Number of products
plt.show()

# %% [markdown]
# #### Exited Vs Estimated Salary

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='EstimatedSalary',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Estimated Salary
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Dummy Variable Creation

# %%
ds = pd.get_dummies(ds,columns=ds.select_dtypes(include=["object"]).columns.tolist(),drop_first=True,dtype=float)

# %% [markdown]
# ### Train-validation-test Split

# %%
X = ds.drop(['Exited'],axis=1) # Credit Score through Estimated Salary
y = ds['Exited'] # Exited

# %%
# Splitting the dataset into the Training and Testing set.

X_large, X_test, y_large, y_test = train_test_split(X, y, test_size =0.25, random_state = 42,stratify=y,shuffle = True) ## Complete the code to Split the X and y and obtain test set

# %%
# Splitting the dataset into the Training and Testing set.

X_train, X_val, y_train, y_val = train_test_split(X_large, y_large, test_size =0.2, random_state = 42,stratify=y_large, shuffle = True) ## complete the code to Split X_large and y_large to obtain train and validation sets

# %%
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (6000, 11) (1500, 11) (2500, 11)

# %%
print(y_train.shape, y_val.shape, y_test.shape)
# Out:
# (6000,) (1500,) (2500,)

# %% [markdown]
# ### Data Normalization

# %% [markdown]
# Since all the numerical values are on a different scale, so we will be scaling all the numerical values to bring them to the same scale.

# %%
# creating an instance of the standard scaler
sc = StandardScaler()

X_train[cols_list] = sc.fit_transform(X_train[cols_list])
X_val[cols_list] = sc.transform(X_val[cols_list])    ## Complete the code to specify the columns to normalize
X_test[cols_list] = sc.transform(X_test[cols_list])    ## Complete the code to specify the columns to normalize

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model Evaluation Criterion

# %% [markdown]
# Write down the logic for choosing the metric that would be the best metric for this business scenario.
#
# -

# %% [markdown]
# **Let's create a function for plotting the confusion matrix**

# %%
def make_confusion_matrix(actual_targets, predicted_targets):
    """
    To plot the confusion_matrix with percentages

    actual_targets: actual target (dependent) variable values
    predicted_targets: predicted target (dependent) variable values
    """
    cm = confusion_matrix(actual_targets, predicted_targets)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(cm.shape[0], cm.shape[1])

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# Let's create two blank dataframes that will store the recall values for all the models we build.

# %%
train_metric_df = pd.DataFrame(columns=["recall"])
valid_metric_df = pd.DataFrame(columns=["recall"])

# %% [markdown]
# ### Neural Network with SGD Optimizer

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_0 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_0.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_0.add(Dense(32, activation='relu'))
# Complete the code to add the output layer with the number of neurons required.
model_0.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use SGD as the optimizer.
optimizer = tf.keras.optimizers.SGD(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
## Complete the code to compile the model with binary cross entropy as loss function and recall as the metric.
model_0.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2881 (11.25 KB)
# Trainable params: 2881 (11.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fitting the ANN

history_0 = model_0.fit(
    X_train, y_train,
    batch_size=32,    ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs=100,    ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 3s 5ms/step - loss: 0.6145 - recall: 0.0777 - val_loss: 0.5859 - val_recall: 0.0033
# Epoch 2/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.5624 - recall: 0.0041 - val_loss: 0.5489 - val_recall: 0.0000e+00
# Epoch 3/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.5341 - recall: 0.0000e+00 - val_loss: 0.5281 - val_recall: 0.0000e+00
# Epoch 4/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.5178 - recall: 0.0000e+00 - val_loss: 0.5156 - val_recall: 0.0000e+00
# Epoch 5/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.5078 - recall: 0.0000e+00 - val_loss: 0.5076 - val_recall: 0.0000e+00
# Epoch 6/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.5011 - recall: 0.0000e+00 - val_loss: 0.5018 - val_recall: 0.0000e+00
# Epoch 7/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4962 - recall: 0.0000e+00 - val_loss: 0.4972 - val_recall: 0.0000e+00
# Epoch 8/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4921 - recall: 0.0000e+00 - val_loss: 0.4934 - val_recall: 0.0000e+00
# Epoch 9/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4887 - recall: 0.0000e+00 - val_loss: 0.4899 - val_recall: 0.0000e+00
# Epoch 10/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4856 - recall: 0.0000e+00 - val_loss: 0.4868 - val_recall: 0.0000e+00
# Epoch 11/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4828 - recall: 0.0000e+00 - val_loss: 0.4840 - val_recall: 0.0000e+00
# Epoch 12/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4802 - recall: 0.0000e+00 - val_loss: 0.4813 - val_recall: 0.0000e+00
# Epoch 13/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4778 - recall: 0.0000e+00 - val_loss: 0.4788 - val_recall: 0.0000e+00
# Epoch 14/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4755 - recall: 0.0000e+00 - val_loss: 0.4763 - val_recall: 0.0000e+00
# Epoch 15/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4733 - recall: 0.0000e+00 - val_loss: 0.4741 - val_recall: 0.0000e+00
# Epoch 16/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4712 - recall: 0.0000e+00 - val_loss: 0.4719 - val_recall: 0.0000e+00
# Epoch 17/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4693 - recall: 8.1833e-04 - val_loss: 0.4698 - val_recall: 0.0000e+00
# Epoch 18/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4674 - recall: 8.1833e-04 - val_loss: 0.4679 - val_recall: 0.0000e+00
# Epoch 19/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4656 - recall: 0.0016 - val_loss: 0.4660 - val_recall: 0.0000e+00
# Epoch 20/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4639 - recall: 0.0016 - val_loss: 0.4642 - val_recall: 0.0000e+00
# Epoch 21/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4622 - recall: 0.0016 - val_loss: 0.4625 - val_recall: 0.0000e+00
# Epoch 22/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4607 - recall: 0.0025 - val_loss: 0.4609 - val_recall: 0.0000e+00
# Epoch 23/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4592 - recall: 0.0041 - val_loss: 0.4593 - val_recall: 0.0000e+00
# Epoch 24/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4577 - recall: 0.0049 - val_loss: 0.4578 - val_recall: 0.0000e+00
# Epoch 25/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4564 - recall: 0.0065 - val_loss: 0.4564 - val_recall: 0.0033
# Epoch 26/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4550 - recall: 0.0090 - val_loss: 0.4550 - val_recall: 0.0033
# Epoch 27/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4538 - recall: 0.0115 - val_loss: 0.4537 - val_recall: 0.0098
# Epoch 28/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4526 - recall: 0.0139 - val_loss: 0.4525 - val_recall: 0.0131
# Epoch 29/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4514 - recall: 0.0188 - val_loss: 0.4513 - val_recall: 0.0196
# Epoch 30/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4503 - recall: 0.0237 - val_loss: 0.4502 - val_recall: 0.0196
# Epoch 31/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4493 - recall: 0.0270 - val_loss: 0.4491 - val_recall: 0.0196
# Epoch 32/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4482 - recall: 0.0286 - val_loss: 0.4480 - val_recall: 0.0229
# Epoch 33/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4473 - recall: 0.0336 - val_loss: 0.4470 - val_recall: 0.0261
# Epoch 34/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4463 - recall: 0.0368 - val_loss: 0.4461 - val_recall: 0.0294
# Epoch 35/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4454 - recall: 0.0385 - val_loss: 0.4452 - val_recall: 0.0294
# Epoch 36/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4446 - recall: 0.0434 - val_loss: 0.4443 - val_recall: 0.0359
# Epoch 37/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4437 - recall: 0.0458 - val_loss: 0.4434 - val_recall: 0.0392
# Epoch 38/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4429 - recall: 0.0532 - val_loss: 0.4426 - val_recall: 0.0425
# Epoch 39/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4422 - recall: 0.0565 - val_loss: 0.4419 - val_recall: 0.0458
# Epoch 40/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4414 - recall: 0.0606 - val_loss: 0.4411 - val_recall: 0.0458
# Epoch 41/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4407 - recall: 0.0630 - val_loss: 0.4404 - val_recall: 0.0588
# Epoch 42/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4401 - recall: 0.0671 - val_loss: 0.4397 - val_recall: 0.0686
# Epoch 43/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4394 - recall: 0.0712 - val_loss: 0.4391 - val_recall: 0.0686
# Epoch 44/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.
100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4254 - recall: 0.1645 - val_loss: 0.4247 - val_recall: 0.1667
# Epoch 79/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4251 - recall: 0.1604 - val_loss: 0.4245 - val_recall: 0.1667
# Epoch 80/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4248 - recall: 0.1653 - val_loss: 0.4242 - val_recall: 0.1699
# Epoch 81/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4246 - recall: 0.1653 - val_loss: 0.4239 - val_recall: 0.1765
# Epoch 82/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4243 - recall: 0.1653 - val_loss: 0.4237 - val_recall: 0.1830
# Epoch 83/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4240 - recall: 0.1686 - val_loss: 0.4234 - val_recall: 0.1863
# Epoch 84/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4238 - recall: 0.1727 - val_loss: 0.4231 - val_recall: 0.1863
# Epoch 85/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4236 - recall: 0.1702 - val_loss: 0.4229 - val_recall: 0.1895
# Epoch 86/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4233 - recall: 0.1727 - val_loss: 0.4226 - val_recall: 0.1895
# Epoch 87/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4231 - recall: 0.1743 - val_loss: 0.4224 - val_recall: 0.1928
# Epoch 88/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4229 - recall: 0.1776 - val_loss: 0.4221 - val_recall: 0.1928
# Epoch 89/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4226 - recall: 0.1751 - val_loss: 0.4219 - val_recall: 0.1961
# Epoch 90/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4224 - recall: 0.1817 - val_loss: 0.4217 - val_recall: 0.1993
# Epoch 91/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4222 - recall: 0.1792 - val_loss: 0.4215 - val_recall: 0.2026
# Epoch 92/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4220 - recall: 0.1825 - val_loss: 0.4212 - val_recall: 0.2026
# Epoch 93/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4218 - recall: 0.1825 - val_loss: 0.4210 - val_recall: 0.2026
# Epoch 94/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4216 - recall: 0.1841 - val_loss: 0.4208 - val_recall: 0.2026
# Epoch 95/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4214 - recall: 0.1858 - val_loss: 0.4206 - val_recall: 0.2026
# Epoch 96/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4211 - recall: 0.1825 - val_loss: 0.4204 - val_recall: 0.2092
# Epoch 97/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4209 - recall: 0.1882 - val_loss: 0.4202 - val_recall: 0.2092
# Epoch 98/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4207 - recall: 0.1882 - val_loss: 0.4199 - val_recall: 0.2092
# Epoch 99/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4206 - recall: 0.1923 - val_loss: 0.4197 - val_recall: 0.2092
# Epoch 100/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4204 - recall: 0.1890 - val_loss: 0.4196 - val_recall: 0.2124

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_0.history['loss'])
plt.plot(history_0.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Recall**

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_0.history['recall'])
plt.plot(history_0.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using best as a threshold
y_train_pred = model_0.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 188/188 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using best as a threshold
y_val_pred = model_0.predict(X_val)    ## Complete the code to make prediction on the validation set
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with SGD"

train_metric_df.loc[model_name] = recall_score(y_train, y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val, y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#lassification report
cr = classification_report(y_train, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.89      4778
#            1       0.68      0.19      0.30      1222
#
#     accuracy                           0.82      6000
#    macro avg       0.75      0.59      0.60      6000
# weighted avg       0.80      0.82      0.77      6000

# %%
#classification report
cr=classification_report(y_val, y_val_pred)    ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1194
#            1       0.64      0.21      0.32       306
#
#     accuracy                           0.81      1500
#    macro avg       0.73      0.59      0.61      1500
# weighted avg       0.79      0.81      0.78      1500

# %% [markdown]
# **Confusion matrix**

# %%
make_confusion_matrix(y_train, y_train_pred)

# %%
make_confusion_matrix(y_val, y_val_pred)    ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ## Model Performance Improvement

# %% [markdown]
# ### Neural Network with Adam Optimizer

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_1 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_1.add(Dense(64,activation='relu',input_dim = X_train.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_1.add(Dense(32,activation='relu'))
#Complete the code to add a output layer with the required number of neurons and relu as activation function
model_1.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2881 (11.25 KB)
# Trainable params: 2881 (11.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Fitting the ANN
history_1 = model_1.fit(
    X_train,y_train,
    batch_size=32, ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs=100, ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 2s 4ms/step - loss: 0.4580 - recall: 0.0900 - val_loss: 0.4218 - val_recall: 0.1699
# Epoch 2/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.4190 - recall: 0.2291 - val_loss: 0.4100 - val_recall: 0.3333
# Epoch 3/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4061 - recall: 0.2921 - val_loss: 0.4017 - val_recall: 0.3660
# Epoch 4/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3963 - recall: 0.3282 - val_loss: 0.3893 - val_recall: 0.3203
# Epoch 5/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3872 - recall: 0.3445 - val_loss: 0.3841 - val_recall: 0.3399
# Epoch 6/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3766 - recall: 0.3674 - val_loss: 0.3792 - val_recall: 0.4118
# Epoch 7/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3711 - recall: 0.3879 - val_loss: 0.3697 - val_recall: 0.4379
# Epoch 8/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3627 - recall: 0.4034 - val_loss: 0.3683 - val_recall: 0.3758
# Epoch 9/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3570 - recall: 0.4182 - val_loss: 0.3623 - val_recall: 0.4248
# Epoch 10/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3495 - recall: 0.4362 - val_loss: 0.3596 - val_recall: 0.3856
# Epoch 11/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3439 - recall: 0.4386 - val_loss: 0.3555 - val_recall: 0.4281
# Epoch 12/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3387 - recall: 0.4468 - val_loss: 0.3578 - val_recall: 0.3824
# Epoch 13/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3359 - recall: 0.4517 - val_loss: 0.3575 - val_recall: 0.5261
# Epoch 14/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3326 - recall: 0.4624 - val_loss: 0.3512 - val_recall: 0.5359
# Epoch 15/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3293 - recall: 0.4828 - val_loss: 0.3458 - val_recall: 0.4771
# Epoch 16/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3250 - recall: 0.4771 - val_loss: 0.3554 - val_recall: 0.5327
# Epoch 17/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3233 - recall: 0.4787 - val_loss: 0.3451 - val_recall: 0.5229
# Epoch 18/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3213 - recall: 0.4869 - val_loss: 0.3450 - val_recall: 0.4739
# Epoch 19/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3193 - recall: 0.4910 - val_loss: 0.3441 - val_recall: 0.5229
# Epoch 20/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3177 - recall: 0.4975 - val_loss: 0.3465 - val_recall: 0.5196
# Epoch 21/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3166 - recall: 0.4935 - val_loss: 0.3569 - val_recall: 0.5850
# Epoch 22/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3149 - recall: 0.5098 - val_loss: 0.3464 - val_recall: 0.5163
# Epoch 23/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3116 - recall: 0.5016 - val_loss: 0.3503 - val_recall: 0.5392
# Epoch 24/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3113 - recall: 0.5123 - val_loss: 0.3426 - val_recall: 0.5196
# Epoch 25/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3104 - recall: 0.5115 - val_loss: 0.3458 - val_recall: 0.5686
# Epoch 26/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3077 - recall: 0.5147 - val_loss: 0.3407 - val_recall: 0.5752
# Epoch 27/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3061 - recall: 0.5237 - val_loss: 0.3559 - val_recall: 0.5261
# Epoch 28/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3084 - recall: 0.5213 - val_loss: 0.3456 - val_recall: 0.5327
# Epoch 29/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3041 - recall: 0.5131 - val_loss: 0.3466 - val_recall: 0.4869
# Epoch 30/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3040 - recall: 0.5164 - val_loss: 0.3482 - val_recall: 0.5033
# Epoch 31/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3003 - recall: 0.5286 - val_loss: 0.3408 - val_recall: 0.5065
# Epoch 32/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2990 - recall: 0.5278 - val_loss: 0.3422 - val_recall: 0.5588
# Epoch 33/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2979 - recall: 0.5417 - val_loss: 0.3485 - val_recall: 0.4673
# Epoch 34/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2999 - recall: 0.5319 - val_loss: 0.3410 - val_recall: 0.5327
# Epoch 35/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2987 - recall: 0.5344 - val_loss: 0.3464 - val_recall: 0.4771
# Epoch 36/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2948 - recall: 0.5327 - val_loss: 0.3460 - val_recall: 0.5294
# Epoch 37/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2952 - recall: 0.5434 - val_loss: 0.3423 - val_recall: 0.5327
# Epoch 38/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2946 - recall: 0.5376 - val_loss: 0.3470 - val_recall: 0.4935
# Epoch 39/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2929 - recall: 0.5426 - val_loss: 0.3438 - val_recall: 0.5588
# Epoch 40/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2925 - recall: 0.5352 - val_loss: 0.3552 - val_recall: 0.5784
# Epoch 41/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2909 - recall: 0.5475 - val_loss: 0.3472 - val_recall: 0.5588
# Epoch 42/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2895 - recall: 0.5556 - val_loss: 0.3467 - val_recall: 0.5458
# Epoch 43/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2894 - recall: 0.5597 - val_loss: 0.3459 - val_recall: 0.5033
# Epoch 44/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2866 - recall: 0.5450 - val_loss: 0.3481 - val_recall: 0.5392
# Epoch 45/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2867 - recall: 0.5630 - val_loss: 0.3469 - val_recall: 0.5229
# Epoch 46/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2857 - recall: 0.5524 - val_loss: 0.3486 - val_recall: 0.5523
# Epoch 47/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2818 - recall: 0.5736 - val_loss: 0.3482 - val_recall: 0.5915
# Epoch 48/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2823 - recall: 0.5671 - val_loss: 0.3538 - val_recall: 0.5654
# Epoch 49/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2828 - recall: 0.5646 - val_loss: 0.3528 - val_recall: 0.5458
# Epoch 50/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2819 - recall: 0.5573 - val_loss: 0.3493 - val_recall: 0.5752
# Epoch 51/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2810 - recall: 0.5786 - val_loss: 0.3508 - val_recall: 0.5294
# Epoch 52/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2773 - recall: 0.5655 - val_loss: 0.3498 - val_recall: 0.5948
# Epoch 53/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2791 - recall: 0.5753 - val_loss: 0.3528 - val_recall: 0.5359
# Epoch 54/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2784 - recall: 0.5671 - val_loss: 0.3557 - val_recall: 0.4935
# Epoch 55/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2775 - recall: 0.5745 - val_loss: 0.3508 - val_recall: 0.5229
# Epoch 56/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2749 - recall: 0.5761 - val_loss: 0.3549 - val_recall: 0.5882
# Epoch 57/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2744 - recall: 0.5818 - val_loss: 0.3498 - val_recall: 0.5588
# Epoch 58/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2734 - recall: 0.5769 - val_loss: 0.3579 - val_recall: 0.5850
# Epoch 59/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2732 - recall: 0.5851 - val_loss: 0.3534 - val_recall: 0.5556
# Epoch 60/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2715 - recall: 0.5794 - val_loss: 0.3665 - val_recall: 0.5033
# Epoch 61/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2706 - recall: 0.5933 - val_loss: 0.3572 - val_recall: 0.5490
# Epoch 62/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2691 - recall: 0.5884 - val_loss: 0.3624 - val_recall: 0.5065
# Epoch 63/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2700 - recall: 0.5859 - val_loss: 0.3619 - val_recall: 0.5915
# Epoch 64/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2674 - recall: 0.6031 - val_loss: 0.3576 - val_recall: 0.5131
# Epoch 65/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2663 - recall: 0.5835 - val_loss: 0.3612 - val_recall: 0.5000
# Epoch 66/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2662 - recall: 0.5990 - val_loss: 0.3583 - val_recall: 0.5719
# Epoch 67/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2665 - recall: 0.5925 - val_loss: 0.3557 - val_recall: 0.5556
# Epoch 68/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2663 - recall: 0.5867 - val_loss: 0.3616 - val_recall: 0.5392
# Epoch 69/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2639 - recall: 0.5966 - val_loss: 0.3656 - val_recall: 0.5131
# Epoch 70/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2642 - recall: 0.5998 - val_loss: 0.3571 - val_recall: 0.5523
# Epoch 71/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2606 - recall: 0.6007 - val_loss: 0.3612 - val_recall: 0.5621
# Epoch 72/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2616 - recall: 0.5998 - val_loss: 0.3598 - val_recall: 0.5850
# Epoch 73/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2613 - recall: 0.6088 - val_loss: 0.3613 - val_recall: 0.5654
# Epoch 74/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2605 - recall: 0.5974 - val_loss: 0.3616 - val_recall: 0.5817
# Epoch 75/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2620 - recall: 0.6097 - val_loss: 0.3642 - val_recall: 0.6176
# Epoch 76/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2584 - recall: 0.6080 - val_loss: 0.3673 - val_recall: 0.4935
# Epoch 77/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2589 - recall: 0.5941 - val_loss: 0.3759 - val_recall: 0.5719
# Epoch 78/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2548 - recall: 0.6097 - val_loss: 0.3700 - val_recall: 0.5163
# Epoch 79/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2576 - recall: 0.6195 - val_loss: 0.3665 - val_recall: 0.5882
# Epoch 80/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2561 - recall: 0.6195 - val_loss: 0.3689 - val_recall: 0.5719
# Epoch 81/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2556 - recall: 0.6203 - val_loss: 0.3648 - val_recall: 0.5621
# Epoch 82/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2544 - recall: 0.6178 - val_loss: 0.3715 - val_recall: 0.5948
# Epoch 83/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2536 - recall: 0.6154 - val_loss: 0.3691 - val_recall: 0.5261
# Epoch 84/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2515 - recall: 0.6268 - val_loss: 0.3719 - val_recall: 0.5425
# Epoch 85/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2506 - recall: 0.6342 - val_loss: 0.3712 - val_recall: 0.5654
# Epoch 86/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2500 - recall: 0.6187 - val_loss: 0.3698 - val_recall: 0.5294
# Epoch 87/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2498 - recall: 0.6268 - val_loss: 0.3760 - val_recall: 0.5131
# Epoch 88/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2506 - recall: 0.6358 - val_loss: 0.3709 - val_recall: 0.5915
# Epoch 89/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2485 - recall: 0.6383 - val_loss: 0.3727 - val_recall: 0.5490
# Epoch 90/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2495 - recall: 0.6236 - val_loss: 0.3688 - val_recall: 0.5458
# Epoch 91/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2490 - recall: 0.6244 - val_loss: 0.3689 - val_recall: 0.5719
# Epoch 92/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2480 - recall: 0.6358 - val_loss: 0.3821 - val_recall: 0.5556
# Epoch 93/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2460 - recall: 0.6318 - val_loss: 0.3799 - val_recall: 0.5425
# Epoch 94/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2450 - recall: 0.6244 - val_loss: 0.3837 - val_recall: 0.5980
# Epoch 95/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2446 - recall: 0.6334 - val_loss: 0.3750 - val_recall: 0.5784
# Epoch 96/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2472 - recall: 0.6334 - val_loss: 0.3791 - val_recall: 0.5882
# Epoch 97/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2446 - recall: 0.6318 - val_loss: 0.3858 - val_recall: 0.5948
# Epoch 98/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2436 - recall: 0.6440 - val_loss: 0.3792 - val_recall: 0.5588
# Epoch 99/100
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2439 - recall: 0.6318 - val_loss: 0.3906 - val_recall: 0.5915
# Epoch 100/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.2419 - recall: 0.6227 - val_loss: 0.3848 - val_recall: 0.5392

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Recall**

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_1.history['recall'])
plt.plot(history_1.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using 0.5 as the threshold
y_train_pred = model_1.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 188/188 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using 0.5 as the threshold
y_val_pred = model_1.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with Adam"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#lassification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      4778
#            1       0.87      0.62      0.72      1222
#
#     accuracy                           0.90      6000
#    macro avg       0.89      0.80      0.83      6000
# weighted avg       0.90      0.90      0.90      6000

# %%
#classification report
cr=classification_report(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1194
#            1       0.74      0.54      0.62       306
#
#     accuracy                           0.87      1500
#    macro avg       0.81      0.75      0.77      1500
# weighted avg       0.86      0.87      0.86      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Adam Optimizer and Dropout

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_2 = Sequential()
#Adding the input layer with 32 neurons and relu as activation function
model_2.add(Dense(32,activation='relu',input_dim = X_train.shape[1]))
# Complete the code to add dropout with ratio of 0.2 or any suitable value.
model_2.add(Dropout(0.2))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(32,activation='relu'))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(16,activation='relu'))
# Complete the code to add dropout with ratio of 0.1 or any suitable value.
model_2.add(Dropout(0.1))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(8,activation='relu'))
# Complete the code to add the number of neurons required in the output layer.
model_2.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
## Complete the code to compile the model with binary cross entropy as loss function and recall as the metric.
model_2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])
# model_2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[keras.metrics.Recall()])

# %%
# Summary of the model
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 2113 (8.25 KB)
# Trainable params: 2113 (8.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Fitting the ANN with batch_size = 32 and 100 epochs
history_2 = model_2.fit(
    X_train,y_train,
    batch_size=32,  ##Complete the code to specify the batch size.
    epochs=100, ##Complete the code to specify the # of epochs.
    verbose=1,
    validation_data=(X_val,y_val)
)
# Out:
# Epoch 1/100
# 188/188 [==============================] - 2s 5ms/step - loss: 0.4950 - recall: 0.0229 - val_loss: 0.4504 - val_recall: 0.0000e+00
# Epoch 2/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4503 - recall: 0.0090 - val_loss: 0.4349 - val_recall: 0.0033
# Epoch 3/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4397 - recall: 0.0655 - val_loss: 0.4303 - val_recall: 0.1144
# Epoch 4/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4391 - recall: 0.1260 - val_loss: 0.4231 - val_recall: 0.1111
# Epoch 5/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4324 - recall: 0.1833 - val_loss: 0.4163 - val_recall: 0.1863
# Epoch 6/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4257 - recall: 0.2422 - val_loss: 0.4079 - val_recall: 0.2778
# Epoch 7/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4164 - recall: 0.2897 - val_loss: 0.3975 - val_recall: 0.2778
# Epoch 8/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4103 - recall: 0.2831 - val_loss: 0.3970 - val_recall: 0.2484
# Epoch 9/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4109 - recall: 0.2807 - val_loss: 0.3923 - val_recall: 0.2712
# Epoch 10/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4040 - recall: 0.2938 - val_loss: 0.3917 - val_recall: 0.2941
# Epoch 11/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4030 - recall: 0.3052 - val_loss: 0.3893 - val_recall: 0.2484
# Epoch 12/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4003 - recall: 0.3216 - val_loss: 0.3827 - val_recall: 0.3039
# Epoch 13/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3934 - recall: 0.3314 - val_loss: 0.3788 - val_recall: 0.3562
# Epoch 14/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3923 - recall: 0.3404 - val_loss: 0.3750 - val_recall: 0.4085
# Epoch 15/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3838 - recall: 0.3707 - val_loss: 0.3653 - val_recall: 0.3562
# Epoch 16/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3809 - recall: 0.3789 - val_loss: 0.3615 - val_recall: 0.4118
# Epoch 17/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3765 - recall: 0.3748 - val_loss: 0.3575 - val_recall: 0.3954
# Epoch 18/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3728 - recall: 0.3846 - val_loss: 0.3542 - val_recall: 0.4150
# Epoch 19/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3731 - recall: 0.3887 - val_loss: 0.3533 - val_recall: 0.4608
# Epoch 20/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3658 - recall: 0.3903 - val_loss: 0.3478 - val_recall: 0.4085
# Epoch 21/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3606 - recall: 0.4149 - val_loss: 0.3465 - val_recall: 0.4444
# Epoch 22/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3616 - recall: 0.4034 - val_loss: 0.3443 - val_recall: 0.4575
# Epoch 23/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3607 - recall: 0.3977 - val_loss: 0.3463 - val_recall: 0.4706
# Epoch 24/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3583 - recall: 0.4165 - val_loss: 0.3433 - val_recall: 0.4510
# Epoch 25/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3567 - recall: 0.4182 - val_loss: 0.3437 - val_recall: 0.4608
# Epoch 26/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3572 - recall: 0.4223 - val_loss: 0.3429 - val_recall: 0.4739
# Epoch 27/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3542 - recall: 0.4124 - val_loss: 0.3454 - val_recall: 0.4510
# Epoch 28/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3534 - recall: 0.4247 - val_loss: 0.3415 - val_recall: 0.4771
# Epoch 29/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3532 - recall: 0.4247 - val_loss: 0.3432 - val_recall: 0.4477
# Epoch 30/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3482 - recall: 0.4296 - val_loss: 0.3414 - val_recall: 0.4706
# Epoch 31/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3489 - recall: 0.4321 - val_loss: 0.3400 - val_recall: 0.4575
# Epoch 32/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3486 - recall: 0.4255 - val_loss: 0.3409 - val_recall: 0.4608
# Epoch 33/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3406 - recall: 0.4370 - val_loss: 0.3428 - val_recall: 0.4673
# Epoch 34/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3472 - recall: 0.4272 - val_loss: 0.3416 - val_recall: 0.5131
# Epoch 35/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3473 - recall: 0.4313 - val_loss: 0.3388 - val_recall: 0.4837
# Epoch 36/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3451 - recall: 0.4362 - val_loss: 0.3396 - val_recall: 0.4771
# Epoch 37/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3412 - recall: 0.4444 - val_loss: 0.3369 - val_recall: 0.5098
# Epoch 38/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3456 - recall: 0.4362 - val_loss: 0.3412 - val_recall: 0.4608
# Epoch 39/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3490 - recall: 0.4255 - val_loss: 0.3388 - val_recall: 0.4771
# Epoch 40/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3387 - recall: 0.4345 - val_loss: 0.3437 - val_recall: 0.4902
# Epoch 41/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3405 - recall: 0.4304 - val_loss: 0.3413 - val_recall: 0.5261
# Epoch 42/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3389 - recall: 0.4484 - val_loss: 0.3401 - val_recall: 0.4935
# Epoch 43/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3406 - recall: 0.4345 - val_loss: 0.3405 - val_recall: 0.4804
# Epoch 44/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3422 - recall: 0.4378 - val_loss: 0.3387 - val_recall: 0.4706
# Epoch 45/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3350 - recall: 0.4624 - val_loss: 0.3383 - val_recall: 0.4379
# Epoch 46/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3342 - recall: 0.4386 - val_loss: 0.3373 - val_recall: 0.4967
# Epoch 47/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3357 - recall: 0.4558 - val_loss: 0.3395 - val_recall: 0.5458
# Epoch 48/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3374 - recall: 0.4591 - val_loss: 0.3394 - val_recall: 0.5033
# Epoch 49/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3351 - recall: 0.4648 - val_loss: 0.3446 - val_recall: 0.5229
# Epoch 50/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3383 - recall: 0.4427 - val_loss: 0.3391 - val_recall: 0.5196
# Epoch 51/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3376 - recall: 0.4444 - val_loss: 0.3372 - val_recall: 0.4510
# Epoch 52/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3361 - recall: 0.4296 - val_loss: 0.3394 - val_recall: 0.5065
# Epoch 53/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3314 - recall: 0.4566 - val_loss: 0.3391 - val_recall: 0.5131
# Epoch 54/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3304 - recall: 0.4755 - val_loss: 0.3395 - val_recall: 0.4542
# Epoch 55/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3365 - recall: 0.4534 - val_loss: 0.3396 - val_recall: 0.4477
# Epoch 56/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.
100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3228 - recall: 0.4763 - val_loss: 0.3473 - val_recall: 0.5065
# Epoch 91/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3229 - recall: 0.4795 - val_loss: 0.3533 - val_recall: 0.5229
# Epoch 92/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3209 - recall: 0.4804 - val_loss: 0.3513 - val_recall: 0.4967
# Epoch 93/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3187 - recall: 0.4738 - val_loss: 0.3480 - val_recall: 0.5033
# Epoch 94/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3190 - recall: 0.4771 - val_loss: 0.3463 - val_recall: 0.4837
# Epoch 95/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3257 - recall: 0.4664 - val_loss: 0.3463 - val_recall: 0.4771
# Epoch 96/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3251 - recall: 0.4542 - val_loss: 0.3462 - val_recall: 0.5392
# Epoch 97/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3197 - recall: 0.4738 - val_loss: 0.3494 - val_recall: 0.5163
# Epoch 98/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3194 - recall: 0.4689 - val_loss: 0.3470 - val_recall: 0.5229
# Epoch 99/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3191 - recall: 0.4787 - val_loss: 0.3471 - val_recall: 0.5098
# Epoch 100/100
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3242 - recall: 0.4542 - val_loss: 0.3544 - val_recall: 0.5196

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we can observe that the train and validation curves are having smooth lines. Reducing the number of neurons and adding dropouts to the model worked, and the problem of overfitting was solved.

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_2.history['recall'])
plt.plot(history_2.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using best as a threshold
y_train_pred = model_2.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 188/188 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using 0.5 as the threshold.
y_val_pred = model_2.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with Adam & Dropout"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#classification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      4778
#            1       0.82      0.53      0.64      1222
#
#     accuracy                           0.88      6000
#    macro avg       0.86      0.75      0.79      6000
# weighted avg       0.88      0.88      0.87      6000

# %%
#classification report
cr = classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1194
#            1       0.68      0.52      0.59       306
#
#     accuracy                           0.85      1500
#    macro avg       0.78      0.73      0.75      1500
# weighted avg       0.84      0.85      0.84      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and SGD Optimizer

# %% [markdown]
# **Let's try to apply SMOTE to balance this dataset and then again apply hyperparamter tuning accordingly.**

# %%
sm  = SMOTE(random_state=42)
#Complete the code to fit SMOTE on the training data.
X_train_smote, y_train_smote= sm.fit_resample(X_train,y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))
# Out:
# After UpSampling, the shape of train_X: (9556, 11)
# After UpSampling, the shape of train_y: (9556,)

# %% [markdown]
# Let's build a model with the balanced dataset

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_3 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_3.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_3.add(Dense(16,activation='relu'))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_3.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer with a sigmoid activation function.
model_3.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use SGD as the optimizer.
optimizer = tf.keras.optimizers.SGD(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1057 (4.13 KB)
# Trainable params: 1057 (4.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Fitting the ANN
history_3 = model_3.fit(
    X_train_smote, y_train_smote,
    batch_size=64, ## Complete the code to specify the batch size to use
    epochs=100, ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/100
# 150/150 [==============================] - 2s 5ms/step - loss: 0.7029 - recall: 0.9479 - val_loss: 0.7420 - val_recall: 0.9346
# Epoch 2/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.7011 - recall: 0.9422 - val_loss: 0.7366 - val_recall: 0.9314
# Epoch 3/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6995 - recall: 0.9341 - val_loss: 0.7317 - val_recall: 0.9183
# Epoch 4/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6981 - recall: 0.9282 - val_loss: 0.7273 - val_recall: 0.9183
# Epoch 5/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6968 - recall: 0.9219 - val_loss: 0.7233 - val_recall: 0.9085
# Epoch 6/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6956 - recall: 0.9100 - val_loss: 0.7196 - val_recall: 0.9052
# Epoch 7/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6944 - recall: 0.9006 - val_loss: 0.7159 - val_recall: 0.9052
# Epoch 8/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6932 - recall: 0.8817 - val_loss: 0.7122 - val_recall: 0.8889
# Epoch 9/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6920 - recall: 0.8610 - val_loss: 0.7084 - val_recall: 0.8529
# Epoch 10/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6906 - recall: 0.8263 - val_loss: 0.7044 - val_recall: 0.8203
# Epoch 11/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6889 - recall: 0.7895 - val_loss: 0.6998 - val_recall: 0.7810
# Epoch 12/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6869 - recall: 0.7453 - val_loss: 0.6945 - val_recall: 0.7484
# Epoch 13/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6848 - recall: 0.7135 - val_loss: 0.6891 - val_recall: 0.7190
# Epoch 14/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6825 - recall: 0.6812 - val_loss: 0.6837 - val_recall: 0.6961
# Epoch 15/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6802 - recall: 0.6601 - val_loss: 0.6786 - val_recall: 0.6895
# Epoch 16/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6781 - recall: 0.6467 - val_loss: 0.6739 - val_recall: 0.6699
# Epoch 17/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6761 - recall: 0.6369 - val_loss: 0.6696 - val_recall: 0.6601
# Epoch 18/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6741 - recall: 0.6277 - val_loss: 0.6656 - val_recall: 0.6634
# Epoch 19/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6723 - recall: 0.6275 - val_loss: 0.6618 - val_recall: 0.6667
# Epoch 20/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6704 - recall: 0.6245 - val_loss: 0.6582 - val_recall: 0.6601
# Epoch 21/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6686 - recall: 0.6231 - val_loss: 0.6546 - val_recall: 0.6503
# Epoch 22/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6667 - recall: 0.6208 - val_loss: 0.6514 - val_recall: 0.6471
# Epoch 23/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6649 - recall: 0.6203 - val_loss: 0.6483 - val_recall: 0.6471
# Epoch 24/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6632 - recall: 0.6195 - val_loss: 0.6455 - val_recall: 0.6438
# Epoch 25/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6614 - recall: 0.6229 - val_loss: 0.6428 - val_recall: 0.6438
# Epoch 26/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6597 - recall: 0.6233 - val_loss: 0.6402 - val_recall: 0.6405
# Epoch 27/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6580 - recall: 0.6224 - val_loss: 0.6376 - val_recall: 0.6438
# Epoch 28/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6564 - recall: 0.6224 - val_loss: 0.6353 - val_recall: 0.6438
# Epoch 29/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6547 - recall: 0.6229 - val_loss: 0.6332 - val_recall: 0.6373
# Epoch 30/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6531 - recall: 0.6235 - val_loss: 0.6313 - val_recall: 0.6438
# Epoch 31/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6514 - recall: 0.6237 - val_loss: 0.6295 - val_recall: 0.6471
# Epoch 32/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6498 - recall: 0.6247 - val_loss: 0.6276 - val_recall: 0.6471
# Epoch 33/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6482 - recall: 0.6247 - val_loss: 0.6258 - val_recall: 0.6471
# Epoch 34/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6465 - recall: 0.6264 - val_loss: 0.6242 - val_recall: 0.6438
# Epoch 35/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6449 - recall: 0.6285 - val_loss: 0.6226 - val_recall: 0.6438
# Epoch 36/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6432 - recall: 0.6321 - val_loss: 0.6211 - val_recall: 0.6438
# Epoch 37/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6416 - recall: 0.6327 - val_loss: 0.6197 - val_recall: 0.6438
# Epoch 38/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6399 - recall: 0.6331 - val_loss: 0.6184 - val_recall: 0.6438
# Epoch 39/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6383 - recall: 0.6365 - val_loss: 0.6170 - val_recall: 0.6471
# Epoch 40/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6366 - recall: 0.6386 - val_loss: 0.6154 - val_recall: 0.6471
# Epoch 41/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6349 - recall: 0.6371 - val_loss: 0.6140 - val_recall: 0.6503
# Epoch 42/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6333 - recall: 0.6409 - val_loss: 0.6127 - val_recall: 0.6569
# Epoch 43/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6316 - recall: 0.6436 - val_loss: 0.6113 - val_recall: 0.6536
# Epoch 44/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6299 - recall: 0.6467 - val_loss: 0.6100 - val_recall: 0.6536
# Epoch 45/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6282 - recall: 0.6469 - val_loss: 0.6089 - val_recall: 0.6503
# Epoch 46/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6266 - recall: 0.6499 - val_loss: 0.6079 - val_recall: 0.6569
# Epoch 47/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6249 - recall: 0.6534 - val_loss: 0.6068 - val_recall: 0.6601
# Epoch 48/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6232 - recall: 0.6563 - val_loss: 0.6058 - val_recall: 0.6601
# Epoch 49/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6216 - recall: 0.6589 - val_loss: 0.6049 - val_recall: 0.6569
# Epoch 50/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6199 - recall: 0.6622 - val_loss: 0.6041 - val_recall: 0.6634
# Epoch 51/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6183 - recall: 0.6632 - val_loss: 0.6033 - val_recall: 0.6699
# Epoch 52/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6167 - recall: 0.6645 - val_loss: 0.6022 - val_recall: 0.6797
# Epoch 53/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6151 - recall: 0.6662 - val_loss: 0.6012 - val_recall: 0.6797
# Epoch 54/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6135 - recall: 0.6676 - val_loss: 0.6006 - val_recall: 0.6863
# Epoch 55/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6119 - recall: 0.6704 - val_loss: 0.5994 - val_recall: 0.6863
# Epoch 56/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6103 - recall: 0.6712 - val_loss: 0.5985 - val_recall: 0.6895
# Epoch 57/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6088 - recall: 0.6720 - val_loss: 0.5975 - val_recall: 0.6895
# Epoch 58/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6073 - recall: 0.6739 - val_loss: 0.5964 - val_recall: 0.6895
# Epoch 59/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.6058 - recall: 0.6748 - val_loss: 0.5954 - val_recall: 0.6830
# Epoch 60/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6043 - recall: 0.6764 - val_loss: 0.5948 - val_recall: 0.6895
# Epoch 61/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6029 - recall: 0.6756 - val_loss: 0.5938 - val_recall: 0.6895
# Epoch 62/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6014 - recall: 0.6777 - val_loss: 0.5930 - val_recall: 0.6961
# Epoch 63/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6000 - recall: 0.6796 - val_loss: 0.5922 - val_recall: 0.7026
# Epoch 64/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5986 - recall: 0.6825 - val_loss: 0.5909 - val_recall: 0.6993
# Epoch 65/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5973 - recall: 0.6812 - val_loss: 0.5903 - val_recall: 0.6993
# Epoch 66/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5960 - recall: 0.6810 - val_loss: 0.5897 - val_recall: 0.6993
# Epoch 67/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5947 - recall: 0.6829 - val_loss: 0.5891 - val_recall: 0.6993
# Epoch 68/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5935 - recall: 0.6842 - val_loss: 0.5887 - val_recall: 0.6961
# Epoch 69/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5923 - recall: 0.6873 - val_loss: 0.5874 - val_recall: 0.6993
# Epoch 70/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5911 - recall: 0.6879 - val_loss: 0.5864 - val_recall: 0.6993
# Epoch 71/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5899 - recall: 0.6886 - val_loss: 0.5858 - val_recall: 0.6993
# Epoch 72/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5888 - recall: 0.6894 - val_loss: 0.5856 - val_recall: 0.7092
# Epoch 73/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5877 - recall: 0.6911 - val_loss: 0.5855 - val_recall: 0.7092
# Epoch 74/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5867 - recall: 0.6932 - val_loss: 0.5850 - val_recall: 0.7124
# Epoch 75/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5857 - recall: 0.6967 - val_loss: 0.5837 - val_recall: 0.7190
# Epoch 76/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5847 - recall: 0.6951 - val_loss: 0.5831 - val_recall: 0.7222
# Epoch 77/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5837 - recall: 0.6984 - val_loss: 0.5819 - val_recall: 0.7222
# Epoch 78/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5828 - recall: 0.6984 - val_loss: 0.5818 - val_recall: 0.7222
# Epoch 79/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5819 - recall: 0.7011 - val_loss: 0.5807 - val_recall: 0.7222
# Epoch 80/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5811 - recall: 0.7001 - val_loss: 0.5804 - val_recall: 0.7222
# Epoch 81/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5803 - recall: 0.7018 - val_loss: 0.5811 - val_recall: 0.7222
# Epoch 82/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5795 - recall: 0.7053 - val_loss: 0.5809 - val_recall: 0.7255
# Epoch 83/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5787 - recall: 0.7059 - val_loss: 0.5806 - val_recall: 0.7255
# Epoch 84/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5780 - recall: 0.7105 - val_loss: 0.5794 - val_recall: 0.7222
# Epoch 85/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5772 - recall: 0.7089 - val_loss: 0.5798 - val_recall: 0.7255
# Epoch 86/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5765 - recall: 0.7137 - val_loss: 0.5776 - val_recall: 0.7255
# Epoch 87/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5759 - recall: 0.7097 - val_loss: 0.5777 - val_recall: 0.7255
# Epoch 88/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5753 - recall: 0.7110 - val_loss: 0.5773 - val_recall: 0.7255
# Epoch 89/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5747 - recall: 0.7101 - val_loss: 0.5772 - val_recall: 0.7222
# Epoch 90/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5741 - recall: 0.7108 - val_loss: 0.5771 - val_recall: 0.7222
# Epoch 91/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5735 - recall: 0.7129 - val_loss: 0.5770 - val_recall: 0.7255
# Epoch 92/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5729 - recall: 0.7126 - val_loss: 0.5767 - val_recall: 0.7288
# Epoch 93/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5724 - recall: 0.7135 - val_loss: 0.5758 - val_recall: 0.7255
# Epoch 94/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5719 - recall: 0.7135 - val_loss: 0.5758 - val_recall: 0.7288
# Epoch 95/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5714 - recall: 0.7168 - val_loss: 0.5748 - val_recall: 0.7288
# Epoch 96/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5709 - recall: 0.7152 - val_loss: 0.5753 - val_recall: 0.7288
# Epoch 97/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5704 - recall: 0.7147 - val_loss: 0.5758 - val_recall: 0.7288
# Epoch 98/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5699 - recall: 0.7164 - val_loss: 0.5761 - val_recall: 0.7288
# Epoch 99/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5695 - recall: 0.7156 - val_loss: 0.5762 - val_recall: 0.7320
# Epoch 100/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5691 - recall: 0.7168 - val_loss: 0.5765 - val_recall: 0.7353

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_3.history['recall'])
plt.plot(history_3.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_3.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 299/299 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
y_val_pred = model_3.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE & SGD"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.72      4778
#            1       0.72      0.72      0.72      4778
#
#     accuracy                           0.72      9556
#    macro avg       0.72      0.72      0.72      9556
# weighted avg       0.72      0.72      0.72      9556

# %%
cr=classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79      1194
#            1       0.39      0.74      0.51       306
#
#     accuracy                           0.71      1500
#    macro avg       0.65      0.72      0.65      1500
# weighted avg       0.81      0.71      0.74      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %%
#Calculating the confusion matrix

make_confusion_matrix(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and Adam Optimizer

# %% [markdown]
# Let's build a model with the balanced dataset

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_4 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_4.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_4.add(Dense(16,activation='relu'))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_4.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer and a suitable activation function.
model_4.add(Dense(1, activation = 'sigmoid'))

# %%
model_4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1057 (4.13 KB)
# Trainable params: 1057 (4.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

#Fitting the ANN

history_4 = model_4.fit(
    X_train_smote,y_train_smote,
    batch_size=64, ## Complete the code to specify the batch size to use
    epochs=100,  ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/100
# 150/150 [==============================] - 2s 5ms/step - loss: 0.6299 - recall: 0.6911 - val_loss: 0.5584 - val_recall: 0.7157
# Epoch 2/100
# 150/150 [==============================] - 1s 3ms/step - loss: 0
compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
#Fitting the ANN

# history_4 = model_4.fit(
  #  X_train_smote,y_train_smote,
  #  batch_size=64, ## Complete the code to specify the batch size to use
  #  epochs=100,  ## Complete the code to specify the number of epochs
  #  verbose=1,
  #  validation_data = (X_val,y_val)
#)

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_4.history['recall'])
plt.plot(history_4.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_4.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 299/299 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
y_val_pred = model_4.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE & Adam"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      4778
#            1       0.84      0.88      0.86      4778
#
#     accuracy                           0.86      9556
#    macro avg       0.86      0.86      0.86      9556
# weighted avg       0.86      0.86      0.86      9556

# %%
cr=classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86      1194
#            1       0.48      0.74      0.59       306
#
#     accuracy                           0.79      1500
#    macro avg       0.70      0.77      0.72      1500
# weighted avg       0.83      0.79      0.80      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE), Adam Optimizer, and Dropout

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_5 = Sequential()
# Complete the code to add required # of neurons to the input layer with relu as activation function
model_5.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add dropout rate
model_5.add(Dropout(0.2))
# Complete the code to add required # neurons to the hidden layer with any activation function.
model_5.add(Dense(16,activation='relu'))
# Complete the code to add dropout rate.
model_5.add(Dropout(0.1))
# Adding hidden layer with 8 neurons with relu as activation function
model_5.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer with a suitable activation function.
model_5.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1057 (4.13 KB)
# Trainable params: 1057 (4.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_5 = model_5.fit(
    X_train_smote,y_train_smote,
    batch_size=64, ## Complete the code to specify the batch size to use
    epochs=100, ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 2s 5ms/step - loss: 0.6507 - recall: 0.6557 - val_loss: 0.5738 - val_recall: 0.6895
# Epoch 2/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5873 - recall: 0.7093 - val_loss: 0.5600 - val_recall: 0.7516
# Epoch 3/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5731 - recall: 0.7235 - val_loss: 0.5649 - val_recall: 0.7680
# Epoch 4/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5620 - recall: 0.7336 - val_loss: 0.5666 - val_recall: 0.7516
# Epoch 5/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5551 - recall: 0.7300 - val_loss: 0.5819 - val_recall: 0.7810
# Epoch 6/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5473 - recall: 0.7440 - val_loss: 0.5537 - val_recall: 0.7549
# Epoch 7/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5380 - recall: 0.7428 - val_loss: 0.5265 - val_recall: 0.7353
# Epoch 8/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5339 - recall: 0.7436 - val_loss: 0.5402 - val_recall: 0.7680
# Epoch 9/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5259 - recall: 0.7560 - val_loss: 0.5380 - val_recall: 0.7582
# Epoch 10/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5159 - recall: 0.7562 - val_loss: 0.5317 - val_recall: 0.7647
# Epoch 11/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5139 - recall: 0.7585 - val_loss: 0.5084 - val_recall: 0.7386
# Epoch 12/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5087 - recall: 0.7566 - val_loss: 0.5024 - val_recall: 0.7484
# Epoch 13/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.5015 - recall: 0.7488 - val_loss: 0.4841 - val_recall: 0.7157
# Epoch 14/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4948 - recall: 0.7505 - val_loss: 0.4921 - val_recall: 0.7124
# Epoch 15/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4903 - recall: 0.7537 - val_loss: 0.5118 - val_recall: 0.7680
# Epoch 16/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4826 - recall: 0.7516 - val_loss: 0.4716 - val_recall: 0.7288
# Epoch 17/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4855 - recall: 0.7597 - val_loss: 0.4717 - val_recall: 0.7157
# Epoch 18/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4812 - recall: 0.7602 - val_loss: 0.4922 - val_recall: 0.7484
# Epoch 19/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4743 - recall: 0.7641 - val_loss: 0.4801 - val_recall: 0.7190
# Epoch 20/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4674 - recall: 0.7633 - val_loss: 0.4914 - val_recall: 0.7582
# Epoch 21/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4718 - recall: 0.7622 - val_loss: 0.4741 - val_recall: 0.7418
# Epoch 22/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4679 - recall: 0.7622 - val_loss: 0.4694 - val_recall: 0.7451
# Epoch 23/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4609 - recall: 0.7652 - val_loss: 0.4864 - val_recall: 0.7712
# Epoch 24/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4599 - recall: 0.7708 - val_loss: 0.4679 - val_recall: 0.7549
# Epoch 25/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4579 - recall: 0.7727 - val_loss: 0.4746 - val_recall: 0.7680
# Epoch 26/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4554 - recall: 0.7767 - val_loss: 0.4545 - val_recall: 0.7549
# Epoch 27/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4525 - recall: 0.7819 - val_loss: 0.4632 - val_recall: 0.7516
# Epoch 28/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4490 - recall: 0.7777 - val_loss: 0.4549 - val_recall: 0.7614
# Epoch 29/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4460 - recall: 0.7848 - val_loss: 0.4423 - val_recall: 0.7353
# Epoch 30/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4429 - recall: 0.7878 - val_loss: 0.4584 - val_recall: 0.7647
# Epoch 31/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4439 - recall: 0.7892 - val_loss: 0.4499 - val_recall: 0.7516
# Epoch 32/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4419 - recall: 0.7901 - val_loss: 0.4441 - val_recall: 0.7451
# Epoch 33/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4394 - recall: 0.7938 - val_loss: 0.4368 - val_recall: 0.7516
# Epoch 34/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4396 - recall: 0.7922 - val_loss: 0.4464 - val_recall: 0.7516
# Epoch 35/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4304 - recall: 0.7928 - val_loss: 0.4549 - val_recall: 0.7582
# Epoch 36/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4341 - recall: 0.7938 - val_loss: 0.4528 - val_recall: 0.7516
# Epoch 37/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4353 - recall: 0.7978 - val_loss: 0.4386 - val_recall: 0.7582
# Epoch 38/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4385 - recall: 0.7945 - val_loss: 0.4579 - val_recall: 0.7582
# Epoch 39/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4306 - recall: 0.8010 - val_loss: 0.4321 - val_recall: 0.7484
# Epoch 40/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4304 - recall: 0.7932 - val_loss: 0.4518 - val_recall: 0.7647
# Epoch 41/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4273 - recall: 0.8033 - val_loss: 0.4613 - val_recall: 0.7647
# Epoch 42/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4300 - recall: 0.8010 - val_loss: 0.4758 - val_recall: 0.7810
# Epoch 43/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4266 - recall: 0.8020 - val_loss: 0.4432 - val_recall: 0.7614
# Epoch 44/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4263 - recall: 0.8045 - val_loss: 0.4369 - val_recall: 0.7451
# Epoch 45/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4280 - recall: 0.8031 - val_loss: 0.4531 - val_recall: 0.7647
# Epoch 46/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4280 - recall: 0.8049 - val_loss: 0.4366 - val_recall: 0.7549
# Epoch 47/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4260 - recall: 0.8091 - val_loss: 0.4672 - val_recall: 0.7712
# Epoch 48/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4265 - recall: 0.8014 - val_loss: 0.4549 - val_recall: 0.7680
# Epoch 49/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4227 - recall: 0.8031 - val_loss: 0.4609 - val_recall: 0.7680
# Epoch 50/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4236 - recall: 0.8091 - val_loss: 0.4497 - val_recall: 0.7516
# Epoch 51/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4241 - recall: 0.8066 - val_loss: 0.4630 - val_recall: 0.7680
# Epoch 52/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4177 - recall: 0.8108 - val_loss: 0.4440 - val_recall: 0.7549
# Epoch 53/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4217 - recall: 0.8064 - val_loss: 0.4406 - val_recall: 0.7582
# Epoch 54/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4186 - recall: 0.8116 - val_loss: 0.4501 - val_recall: 0.7516
# Epoch 55/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4207 - recall: 0.8016 - val_loss: 0.4465 - val_recall: 0.7549
# Epoch 56/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4203 - recall: 0.8108 - val_loss: 0.4426 - val_recall: 0.7418
# Epoch 57/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4185 - recall: 0.8083 - val_loss: 0.4434 - val_recall: 0.7516
# Epoch 58/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4155 - recall: 0.8133 - val_loss: 0.4396 - val_recall: 0.7451
# Epoch 59/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4180 - recall: 0.8098 - val_loss: 0.4532 - val_recall: 0.7680
# Epoch 60/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4143 - recall: 0.8129 - val_loss: 0.4408 - val_recall: 0.7549
# Epoch 61/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4204 - recall: 0.8041 - val_loss: 0.4551 - val_recall: 0.7680
# Epoch 62/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4196 - recall: 0.8123 - val_loss: 0.4255 - val_recall: 0.7353
# Epoch 63/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4130 - recall: 0.8070 - val_loss: 0.4462 - val_recall: 0.7484
# Epoch 64/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4148 - recall: 0.8137 - val_loss: 0.4241 - val_recall: 0.7386
# Epoch 65/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4113 - recall: 0.8162 - val_loss: 0.4441 - val_recall: 0.7549
# Epoch 66/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4174 - recall: 0.8162 - val_loss: 0.4491 - val_recall: 0.7516
# Epoch 67/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4138 - recall: 0.8098 - val_loss: 0.4337 - val_recall: 0.7484
# Epoch 68/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4117 - recall: 0.8190 - val_loss: 0.4395 - val_recall: 0.7549
# Epoch 69/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4132 - recall: 0.8146 - val_loss: 0.4446 - val_recall: 0.7712
# Epoch 70/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4098 - recall: 0.8150 - val_loss: 0.4322 - val_recall: 0.7549
# Epoch 71/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4125 - recall: 0.8081 - val_loss: 0.4389 - val_recall: 0.7680
# Epoch 72/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4164 - recall: 0.8125 - val_loss: 0.4560 - val_recall: 0.7745
# Epoch 73/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4149 - recall: 0.8016 - val_loss: 0.4784 - val_recall: 0.7810
# Epoch 74/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4118 - recall: 0.8217 - val_loss: 0.4374 - val_recall: 0.7516
# Epoch 75/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4105 - recall: 0.8181 - val_loss: 0.4294 - val_recall: 0.7386
# Epoch 76/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4114 - recall: 0.8213 - val_loss: 0.4450 - val_recall: 0.7647
# Epoch 77/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4086 - recall: 0.8154 - val_loss: 0.4356 - val_recall: 0.7549
# Epoch 78/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4086 - recall: 0.8135 - val_loss: 0.4553 - val_recall: 0.7712
# Epoch 79/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4114 - recall: 0.8144 - val_loss: 0.4343 - val_recall: 0.7516
# Epoch 80/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4068 - recall: 0.8165 - val_loss: 0.4329 - val_recall: 0.7549
# Epoch 81/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4087 - recall: 0.8148 - val_loss: 0.4576 - val_recall: 0.7680
# Epoch 82/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4058 - recall: 0.8175 - val_loss: 0.4369 - val_recall: 0.7484
# Epoch 83/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4016 - recall: 0.8179 - val_loss: 0.4585 - val_recall: 0.7745
# Epoch 84/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4088 - recall: 0.8171 - val_loss: 0.4407 - val_recall: 0.7549
# Epoch 85/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4050 - recall: 0.8183 - val_loss: 0.4439 - val_recall: 0.7778
# Epoch 86/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4083 - recall: 0.8181 - val_loss: 0.4225 - val_recall: 0.7353
# Epoch 87/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4089 - recall: 0.8066 - val_loss: 0.4406 - val_recall: 0.7582
# Epoch 88/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4058 - recall: 0.8196 - val_loss: 0.4241 - val_recall: 0.7582
# Epoch 89/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4031 - recall: 0.8146 - val_loss: 0.4393 - val_recall: 0.7614
# Epoch 90/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4031 - recall: 0.8123 - val_loss: 0.4356 - val_recall: 0.7516
# Epoch 91/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4009 - recall: 0.8206 - val_loss: 0.4345 - val_recall: 0.7549
# Epoch 92/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4048 - recall: 0.8165 - val_loss: 0.4345 - val_recall: 0.7549
# Epoch 93/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4059 - recall: 0.8208 - val_loss: 0.4264 - val_recall: 0.7516
# Epoch 94/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.3998 - recall: 0.8171 - val_loss: 0.4287 - val_recall: 0.7484
# Epoch 95/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4011 - recall: 0.8190 - val_loss: 0.4319 - val_recall: 0.7484
# Epoch 96/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4019 - recall: 0.8144 - val_loss: 0.4158 - val_recall: 0.7418
# Epoch 97/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4057 - recall: 0.8183 - val_loss: 0.4354 - val_recall: 0.7451
# Epoch 98/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4061 - recall: 0.8194 - val_loss: 0.4444 - val_recall: 0.7647
# Epoch 99/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4041 - recall: 0.8200 - val_loss: 0.4495 - val_recall: 0.7647
# Epoch 100/100
# 150/150 [==============================] - 1s 4ms/step - loss: 0.3988 - recall: 0.8190 - val_loss: 0.4347 - val_recall: 0.7516

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_5.history['recall'])
plt.plot(history_5.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_5.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 299/299 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
y_val_pred = model_5.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE,Adam & Dropout"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      4778
#            1       0.83      0.85      0.84      4778
#
#     accuracy                           0.84      9556
#    macro avg       0.84      0.84      0.84      9556
# weighted avg       0.84      0.84      0.84      9556

# %%
#classification report
cr=classification_report(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1194
#            1       0.52      0.75      0.61       306
#
#     accuracy                           0.81      1500
#    macro avg       0.72      0.79      0.74      1500
# weighted avg       0.84      0.81      0.82      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ## Model Performance Comparison and Final Model Selection

# %%
print("Training performance comparison")
train_metric_df
# Out:
# Training performance comparison
#                                 recall
# NN with SGD                   0.193944
# NN with Adam                  0.618658
# NN with Adam & Dropout        0.529460
# NN with SMOTE & SGD           0.719548
# NN with SMOTE & Adam          0.883843
# NN with SMOTE,Adam & Dropout  0.847426

# %%
print("Validation set performance comparison")
valid_metric_df
# Out:
# Validation set performance comparison
#                                 recall
# NN with SGD                   0.212418
# NN with Adam                  0.539216
# NN with Adam & Dropout        0.519608
# NN with SMOTE & SGD           0.735294
# NN with SMOTE & Adam          0.738562
# NN with SMOTE,Adam & Dropout  0.751634

# %%
train_metric_df - valid_metric_df
# Out:
#                                 recall
# NN with SGD                  -0.018474
# NN with Adam                  0.079442
# NN with Adam & Dropout        0.009852
# NN with SMOTE & SGD          -0.015746
# NN with SMOTE & Adam          0.145281
# NN with SMOTE,Adam & Dropout  0.095792

# %%
y_test_pred = model_5.predict(X_test)    ## Complete the code to specify the best model
y_test_pred = (y_test_pred > 0.5)
print(y_test_pred)
# Out:
# 79/79 [==============================] - 0s 1ms/step
# [[False]
#  [False]
#  [False]
#  ...
#  [ True]
#  [False]
#  [False]]

# %%
#lets print classification report
cr=classification_report(y_test,y_test_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1991
#            1       0.49      0.75      0.59       509
#
#     accuracy                           0.79      2500
#    macro avg       0.71      0.78      0.73      2500
# weighted avg       0.84      0.79      0.81      2500

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_test,y_test_pred)

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# *

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
